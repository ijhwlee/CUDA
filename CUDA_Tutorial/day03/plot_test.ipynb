# %% [markdown]
# # Program to test using VSCODE Jupyter notebook for image

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [4, 5, 6])
plt.title("Inline Plot")
plt.show()
